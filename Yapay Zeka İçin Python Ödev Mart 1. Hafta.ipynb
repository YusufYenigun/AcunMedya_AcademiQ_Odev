# %% [markdown]
# # Yapay Zeka için Python Ödev Mart 1. Hafta

# %%
import numpy as np
import pandas as pd

df = pd.read_excel(r"C:\Users\Yusuf\Desktop\Anaconda_Code\teknolojik_urunler1.xlsx")
print(df) #Exel dosyasını okuma fonksiyonudur
# Out:
#     Ürün No                 Ürün Adı            Kategori  Satış  Fiyat (TL)  \
# 0         1           Akıllı Telefon      Mobil Cihazlar     10      5000.0
# 1         2       Dizüstü Bilgisayar       Bilgisayarlar      7      8500.0
# 2         3                   Tablet      Mobil Cihazlar     15         NaN
# 3         4              Akıllı Saat         Aksesuarlar     23      1500.0
# 4         5        Kablosuz Kulaklık         Aksesuarlar     25       800.0
# 5         6             Oyun Konsolu      Oyun Cihazları      5      4000.0
# 6         7      Masaüstü Bilgisayar       Bilgisayarlar      3         NaN
# 7         8       Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12      2000.0
# 8         9            4K Televizyon       Televizyonlar      8      7500.0
# 9        10       Bluetooth Hoparlör         Aksesuarlar     18         NaN
# 10       11          E-kitap Okuyucu      Mobil Cihazlar     23      2500.0
# ...

# %%
df.dropna() #Boş olan Satırları ortadan kaldırma
# Out:
#     Ürün No                 Ürün Adı            Kategori  Satış  Fiyat (TL)  \
# 0         1           Akıllı Telefon      Mobil Cihazlar     10      5000.0
# 1         2       Dizüstü Bilgisayar       Bilgisayarlar      7      8500.0
# 3         4              Akıllı Saat         Aksesuarlar     23      1500.0
# 4         5        Kablosuz Kulaklık         Aksesuarlar     25       800.0
# 5         6             Oyun Konsolu      Oyun Cihazları      5      4000.0
# 7         8       Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12      2000.0
# 8         9            4K Televizyon       Televizyonlar      8      7500.0
# 10       11          E-kitap Okuyucu      Mobil Cihazlar     23      2500.0
# 11       12            Oyun Klavyesi         Aksesuarlar     30       900.0
# 12       13  Sanal Gerçeklik Gözlüğü      Oyun Cihazları      4      4500.0
# 13       14                    Drone         Aksesuarlar      6      6000.0
# ...

# %%
df.isnull() # Boş degerleri bulup true yazıyor geri kalan false
# Out:
#     Ürün No  Ürün Adı  Kategori  Satış  Fiyat (TL)  Toplam Fiyat (TL)
# 0     False     False     False  False       False              False
# 1     False     False     False  False       False              False
# 2     False     False     False  False        True              False
# 3     False     False     False  False       False              False
# 4     False     False     False  False       False              False
# 5     False     False     False  False       False              False
# 6     False     False     False  False        True              False
# 7     False     False     False  False       False              False
# 8     False     False     False  False       False              False
# 9     False     False     False  False        True              False
# 10    False     False     False  False       False              False
# 11    False     False     False  False       False              False
# ...

# %%
df.fillna(0) #Boş olan yerlere istedigimiz degeri atamamızı saglıyor
# Out:
#     Ürün No                 Ürün Adı            Kategori  Satış  Fiyat (TL)  \
# 0         1           Akıllı Telefon      Mobil Cihazlar     10      5000.0
# 1         2       Dizüstü Bilgisayar       Bilgisayarlar      7      8500.0
# 2         3                   Tablet      Mobil Cihazlar     15         0.0
# 3         4              Akıllı Saat         Aksesuarlar     23      1500.0
# 4         5        Kablosuz Kulaklık         Aksesuarlar     25       800.0
# 5         6             Oyun Konsolu      Oyun Cihazları      5      4000.0
# 6         7      Masaüstü Bilgisayar       Bilgisayarlar      3         0.0
# 7         8       Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12      2000.0
# 8         9            4K Televizyon       Televizyonlar      8      7500.0
# 9        10       Bluetooth Hoparlör         Aksesuarlar     18         0.0
# 10       11          E-kitap Okuyucu      Mobil Cihazlar     23      2500.0
# ...

# %%
df.replace(np.nan, 1) #İstediğimi değerleri yazıp yine istediğimiz değerle değiştirmek
# Out:
#     Ürün No                 Ürün Adı            Kategori  Satış  Fiyat (TL)  \
# 0         1           Akıllı Telefon      Mobil Cihazlar     10      5000.0
# 1         2       Dizüstü Bilgisayar       Bilgisayarlar      7      8500.0
# 2         3                   Tablet      Mobil Cihazlar     15         1.0
# 3         4              Akıllı Saat         Aksesuarlar     23      1500.0
# 4         5        Kablosuz Kulaklık         Aksesuarlar     25       800.0
# 5         6             Oyun Konsolu      Oyun Cihazları      5      4000.0
# 6         7      Masaüstü Bilgisayar       Bilgisayarlar      3         1.0
# 7         8       Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12      2000.0
# 8         9            4K Televizyon       Televizyonlar      8      7500.0
# 9        10       Bluetooth Hoparlör         Aksesuarlar     18         1.0
# 10       11          E-kitap Okuyucu      Mobil Cihazlar     23      2500.0
# ...

# %%
df.head(8) #Tablonun kaç değerini almak istiyorsak içine yazıyoruz
# Out:
#    Ürün No             Ürün Adı            Kategori  Satış  Fiyat (TL)  \
# 0        1       Akıllı Telefon      Mobil Cihazlar     10      5000.0
# 1        2   Dizüstü Bilgisayar       Bilgisayarlar      7      8500.0
# 2        3               Tablet      Mobil Cihazlar     15         NaN
# 3        4          Akıllı Saat         Aksesuarlar     23      1500.0
# 4        5    Kablosuz Kulaklık         Aksesuarlar     25       800.0
# 5        6         Oyun Konsolu      Oyun Cihazları      5      4000.0
# 6        7  Masaüstü Bilgisayar       Bilgisayarlar      3         NaN
# 7        8   Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12      2000.0
#
#    Toplam Fiyat (TL)
# 0              50000
# 1              59500
# 2              45000
# 3              30000
# 4              20000
# 5              20000
# 6              30000
# 7              24000

# %%
df.loc[:,["Ürün Adı","Satış"]] # istediğimiz satır ve sütünları seçmek için kullanırız.
# Out:
#                    Ürün Adı  Satış
# 0            Akıllı Telefon     10
# 1        Dizüstü Bilgisayar      7
# 2                    Tablet     15
# 3               Akıllı Saat     23
# 4         Kablosuz Kulaklık     25
# 5              Oyun Konsolu      5
# 6       Masaüstü Bilgisayar      3
# 7        Akıllı Ev Asistanı     12
# 8             4K Televizyon      8
# 9        Bluetooth Hoparlör     18
# 10          E-kitap Okuyucu     23
# 11            Oyun Klavyesi     30
# 12  Sanal Gerçeklik Gözlüğü      4
# 13                    Drone      6
# 14          Akıllı Bileklik     22
# 15     Kablosuz Şarj Cihazı     27
# 16         Akıllı Termostat     23
# 17        Güvenlik Kamerası     11
# 18            Robot Süpürge     13
# 19                  Monitör     10

# %%
df.iloc[ : 12 , : ] #İçine yazdığımız deger ya da deger aralıkları kadar veriyi alır
# Out:
#     Ürün No             Ürün Adı            Kategori  Satış  Fiyat (TL)  \
# 0         1       Akıllı Telefon      Mobil Cihazlar     10      5000.0
# 1         2   Dizüstü Bilgisayar       Bilgisayarlar      7      8500.0
# 2         3               Tablet      Mobil Cihazlar     15         NaN
# 3         4          Akıllı Saat         Aksesuarlar     23      1500.0
# 4         5    Kablosuz Kulaklık         Aksesuarlar     25       800.0
# 5         6         Oyun Konsolu      Oyun Cihazları      5      4000.0
# 6         7  Masaüstü Bilgisayar       Bilgisayarlar      3         NaN
# 7         8   Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12      2000.0
# 8         9        4K Televizyon       Televizyonlar      8      7500.0
# 9        10   Bluetooth Hoparlör         Aksesuarlar     18         NaN
# 10       11      E-kitap Okuyucu      Mobil Cihazlar     23      2500.0
# 11       12        Oyun Klavyesi         Aksesuarlar     30       900.0
#
#     Toplam Fiyat (TL)
# ...

# %%
df.groupby("Kategori")["Toplam Fiyat (TL)"].sum() #İstediğimiz sütünü getirip istediğimiz oradan istediğimiz değerleri gösteriyor
# Out:
# Kategori
# Aksesuarlar           179400
# Akıllı Ev Ürünleri    142100
# Bilgisayarlar         119500
# Mobil Cihazlar        130000
# Oyun Cihazları         38000
# Televizyonlar          60000
# Name: Toplam Fiyat (TL), dtype: int64

# %%
df.insert(1,"Ürün ID",range(80,80+len(df))) #Sütun ekleme Fonksiyonudur.

# %%
print(df)
# Out:
#     Ürün No  Ürün ID                 Ürün Adı            Kategori  Satış  \
# 0         1       80           Akıllı Telefon      Mobil Cihazlar     10
# 1         2       81       Dizüstü Bilgisayar       Bilgisayarlar      7
# 2         3       82                   Tablet      Mobil Cihazlar     15
# 3         4       83              Akıllı Saat         Aksesuarlar     23
# 4         5       84        Kablosuz Kulaklık         Aksesuarlar     25
# 5         6       85             Oyun Konsolu      Oyun Cihazları      5
# 6         7       86      Masaüstü Bilgisayar       Bilgisayarlar      3
# 7         8       87       Akıllı Ev Asistanı  Akıllı Ev Ürünleri     12
# 8         9       88            4K Televizyon       Televizyonlar      8
# 9        10       89       Bluetooth Hoparlör         Aksesuarlar     18
# 10       11       90          E-kitap Okuyucu      Mobil Cihazlar     23
# 11       12       91            Oyun Klavyesi         Aksesuarlar     30
# ...
